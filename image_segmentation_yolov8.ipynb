# %% [markdown]
# <a href="https://colab.research.google.com/github/alaminsayed/pytorch_computer_vision/blob/main/image_segmentation_yolov8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
DATA_DIR = '/content/drive/MyDrive/computer vision'

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 910.1/910.1 kB 25.9 MB/s eta 0:00:00
# ...

# %%
import os

from ultralytics import YOLO


model = YOLO('yolov8n-seg.pt')  # load a pretrained model (recommended for training)

model.train(data='/content/drive/MyDrive/computer vision/config.yaml', epochs=10, imgsz=640)
# Out:
# Ultralytics 8.3.62 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
import locale
locale.getpreferredencoding = lambda: 'UTF-8'

get_ipython().system("scp -r /content/runs '/content/drive/MyDrive/computer vision'")
